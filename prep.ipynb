# %% [markdown]
# # Hashing

# %% [markdown]
# Hashing er en måde at tage et univers af udfald og opbevare det i mindre plads.
#
# Det er basically et dictionary, hvor du ved hjælp af en key kan få værdier tilbage.
#
# F.eks. antag at du vil gemme et ord og dens defintion to arrays.
#
# Normal skal man søge igennem arrayet for at finde ordet og få dets index, som man kan bruge til at tilgå definitionen i det andet arrayy.
#
# Med et hash definerer man længden af arrayesne på forhånd.
#
# Man definerer en også en hash funktion, der returnere et tal mellem 0 og længden af arrayet.
#
# Man tager ordet _hash('word')_ og få returneret et tal.
#
# Du kan nu gemme ordet dette index på et array
#
# Du kan også gemme definitionen på samme index plads i det andet array.
#
# Nu skal du ikke søge, du kan altid direkte få resultatet.
#
# ![](attachment:image.png)

# %%
class Hash_mapper():
    def __init__(self, length):
        self.table = [None] * length
